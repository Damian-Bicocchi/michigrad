# %%
from michigrad.engine import Value
from michigrad.visualize import show_graph, show_graph_interactive
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 from michigrad.engine import Value
# ----> 2 from michigrad.visualize import show_graph, show_graph_interactive
#       3 import numpy as np
#
# File ~/Documentos/leia_tp9/michigrad/michigrad/visualize.py:1
# ----> 1 import networkx as nx
#       2 import pyvis
#       3 from pyvis.network import Network
#
# ModuleNotFoundError: No module named 'networkx'

# %%
a = Value(2,name='a')
b = Value(5,name='b')
c = Value(5,name='c')
f = (a*b)+c
f.name='f'

# %%
c = a+b

# %%
c.name='c'

# %%
show_graph(c)

# %%
# ReLU(x0 * W0 + x1 * W1)
x0 = Value(2,name='x0')
x1 = Value(2,name='x1')
x2 = Value(2,name='x2')
W0 = Value(np.random.randn(), name=f'W0')
W1 = Value(np.random.randn(), name=f'W1')
W2 = Value(np.random.randn(), name=f'W2')
x0W0 = x0 * W0
x0W0.name = 'x0*W0'
x1W1 = x1 * W1
x1W1.name = 'x1*W1'
x2W2 = x2 * W2
x2W2.name = 'x2*W2'
suma1 = x0W0 + x1W1
suma1.name = 'x0W0+x1W1'
suma2 = suma1 + x2W2
suma2.name = 'Σ (x0W0+x1W1+x2W2)'
#suma2.name = "Σ"
relu = suma2.relu()
relu.name = "ReLU"
show_graph(relu)

# %%
show_graph_interactive(relu)
# Out:
# graph.html
